# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('50_Startups.csv.xls')

# %%
data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
data.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
data.isnull().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
type(data.isnull().sum())
# Out:
# pandas.core.series.Series

# %%
data.isnull().sum()[0]
# Out:
# 0

# %%
data.isnull().sum()['R&D Spend']
# Out:
# 0

# %%
data.isnull().sum()[['R&D Spend','Profit']]
# Out:
# R&D Spend    0
# Profit       0
# dtype: int64

# %%
data.State.unique()
# Out:
# array(['New York', 'California', 'Florida'], dtype=object)

# %%
df= pd.get_dummies(data['State'],prefix='State',drop_first=True,dtype=int)

# %%
df.head()
# Out:
#    State_Florida  State_New York
# 0              0               1
# 1              0               0
# 2              1               0
# 3              0               1
# 4              1               0

# %%
data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
final_data=pd.concat([df,data],axis=1)

# %%
final_data.head()
# Out:
#    State_Florida  State_New York  R&D Spend  Administration  Marketing Spend  \
# 0              0               1  165349.20       136897.80        471784.10
# 1              0               0  162597.70       151377.59        443898.53
# 2              1               0  153441.51       101145.55        407934.54
# 3              0               1  144372.41       118671.85        383199.62
# 4              1               0  142107.34        91391.77        366168.42
#
#         State     Profit
# 0    New York  192261.83
# 1  California  191792.06
# 2     Florida  191050.39
# 3    New York  182901.99
# 4     Florida  166187.94

# %%
final_data.drop('State',axis=1,inplace=True)

# %%
final_data.head()
# Out:
#    State_Florida  State_New York  R&D Spend  Administration  Marketing Spend  \
# 0              0               1  165349.20       136897.80        471784.10
# 1              0               0  162597.70       151377.59        443898.53
# 2              1               0  153441.51       101145.55        407934.54
# 3              0               1  144372.41       118671.85        383199.62
# 4              1               0  142107.34        91391.77        366168.42
#
#       Profit
# 0  192261.83
# 1  191792.06
# 2  191050.39
# 3  182901.99
# 4  166187.94

# %%
X=final_data.iloc[:,0:5].values

# %%
y = final_data.iloc[:5].values

# %%
print(type(X))
print(X.ndim)
# Out:
# <class 'numpy.ndarray'>
# 2

# %%
print(type(y))
print(y.ndim)
# Out:
# <class 'numpy.ndarray'>
# 2

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=.20,random_state=101)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 2
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=.20,random_state=101)
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
# ...
